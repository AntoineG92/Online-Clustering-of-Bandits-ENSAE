# %% [markdown]
# # CLUB algorithm draft - Online Clustering of Bandits

# %% [markdown]
# Antoine GRELETY
#
# Vincent LE MEUR

# %%
import numpy as np
import numpy.random as npr
import numpy.linalg
import pandas as pd
from scipy.spatial.distance import euclidean
import networkx as nx
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
import online_cluster

# %%
n_user=80
T=5000
D=5
c=5
Online =online_cluster.OLCB(T=T,n_user=n_user,D=D,c=3,graph_density=3*int(np.log(n_user)*n_user))
Online_UCB_IND =online_cluster.OLCB(T=T,n_user=n_user,D=D,c=c,graph_density=1)

# %% [markdown]
# On représente tous les n_users :

# %%
nx.draw(Online.V)
plt.show()

# %%
#paramètrage des algorithmes
sigma=0.3
alpha=5
alpha2=1
z=0
method = "random design"

# %% [markdown]
# #### Algorithme CLUB

# %%
list_m, list_CB, list_omega, list_payoff, list_random_payoff, regret_cum, regret_cum_random, V = Online.CLUB(sigma=sigma,alpha=alpha,alpha2=alpha2,z=z,method=method)

# %% [markdown]
# #### Algorithme UCB_IND (pas de cluster)

# %%
payoff_UCB_IND, rand_payoff_IND, regret_cum_UCB_IND, regret_cum_rand_UCB_IND, V_IND = Online_UCB_IND.CLUB(sigma=sigma,alpha=alpha,alpha2=alpha2,z=z,method=method)[3:]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6f555f7ee7b0> in <module>()
# ----> 1 payoff_UCB_IND, rand_payoff_IND, regret_cum_UCB_IND, regret_cum_rand_UCB_IND, V_IND = Online_UCB_IND.CLUB(sigma=sigma,alpha=alpha,alpha2=alpha2,z=z,method=method)[3:]
#
# ~/Documents/GitHub/Online-Clustering-of-Bandits-ENSAE/online_cluster.py in CLUB(self, sigma, alpha, alpha2, z, method)
#     148                             V.remove_edge(i,l)
#     149
# --> 150             m=len( list( nx.connected_component_subgraphs(V) ) )
#     151             list_m.append(m)
#     152
#
# ~/anaconda/lib/python3.5/site-packages/networkx/algorithms/components/connected.py in connected_component_subgraphs(G, copy)
#     122     for c in connected_components(G):
#     123         if copy:
# --> 124             yield G.subgraph(c).copy()
#     125         else:
#     126             yield G.subgraph(c)
#
# ~/anaconda/lib/python3.5/site-packages/networkx/classes/graph.py in copy(self, as_view)
#    1419         G.add_nodes_from((n, d.copy()) for n, d in self._node.items())
#    1420         G.add_edges_from((u, v, datadict.copy())
# -> 1421                          for u, nbrs in self.adj.items()
#    1422                          for v, datadict in nbrs.items())
#    1423         return G
#
# ~/anaconda/lib/python3.5/site-packages/networkx/classes/graph.py in add_edges_from(self, ebunch, **attr)
#     921         """
#     922         # process ebunch
# --> 923         for e in ebunch:
#     924             ne = len(e)
#     925             if ne == 3:
#
# ~/anaconda/lib/python3.5/site-packages/networkx/classes/graph.py in <genexpr>(.0)
#    1418         G.graph.update(self.graph)
#    1419         G.add_nodes_from((n, d.copy()) for n, d in self._node.items())
# -> 1420         G.add_edges_from((u, v, datadict.copy())
#    1421                          for u, nbrs in self.adj.items()
#    1422                          for v, datadict in nbrs.items())
#
# ~/anaconda/lib/python3.5/_collections_abc.py in __iter__(self)
#     676
#     677     def __iter__(self):
# --> 678         for key in self._mapping:
#     679             yield (key, self._mapping[key])
#     680
#
# ~/anaconda/lib/python3.5/site-packages/networkx/classes/coreviews.py in <genexpr>(.0)
#     319
#     320     def __iter__(self):
# --> 321         return (n for n in self._atlas if self.NODE_OK(n))
#     322
#     323     def __getitem__(self, node):
#
# ~/anaconda/lib/python3.5/site-packages/networkx/classes/filters.py in __call__(self, node)
#      57
#      58     def __call__(self, node):
# ---> 59         return node in self.nodes
#      60
#      61
#
# KeyboardInterrupt:

# %% [markdown]
# #### Algorithme LINUCB_IND

# %%
list_payoff_Lin,regret_cum_Lin = Online.LinUCB_IND(sigma=sigma,alpha=alpha,method=method)

# %% [markdown]
# Regardons l'évolution du nombre de Cluster au fur et à mesure des ittérations :

# %%
plt.plot(list_m)
plt.title("Evolution du nombre de cluster")
plt.show()

# %% [markdown]
# Observons l'évolution des Confidence Bound :

# %%
plt.plot(list_CB)
plt.legend("Evolution des Confidence Bound")
plt.show()

# %% [markdown]
# Observons l'évolution de la payoff cumulée en fonction des ittérations :

# %%
#mean payoff cumulée
payoff_mean_cum=np.zeros(Online.T)
payoff_vec=np.array(list_payoff)
for i in range(1,Online.T):
    payoff_mean_cum[i]=np.mean(payoff_vec[:i])

plt.plot(Online.payoff_cum(list_payoff)[1000:Online.T])
plt.plot(Online_UCB_IND.payoff_cum(payoff_UCB_IND)[1000:Online_UCB_IND.T])
plt.title("Evolution de la payoff cumulée")
plt.legend(["CLUB","UCB IND"])
plt.show()

# %% [markdown]
# Observons enfin le regret cumulé associé :

# %%
#plt.plot(-regret_cum_random)
plt.plot(regret_cum/regret_cum_random)
plt.plot(regret_cum_UCB_IND/regret_cum_rand_UCB_IND)
plt.legend(["CLUB","UCB_IND"])
plt.xlim(1000,)
plt.ylim(0,1)
plt.xlabel("itérations")
plt.ylabel("regret cumulé relatif")
plt.show()

# %% [markdown]
# Les nouveux clusters sont :

# %%
nx.draw(V)
plt.show()
