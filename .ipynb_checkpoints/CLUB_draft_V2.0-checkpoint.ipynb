# %% [markdown]
# # CLUB algorithm draft - Online Clustering of Bandits

# %% [markdown]
# Antoine GRELETY
#
# Vincent LE MEUR

# %%
import numpy as np
import numpy.random as npr
import numpy.linalg
import pandas as pd
from scipy.spatial.distance import euclidean
import networkx as nx
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
import online_cluster

# %%
n_user=60
n_cluster=3
T=15500
D=5
c=5
Online =online_cluster.OLCB(T=T,n_user=n_user,n_cluster=n_cluster,D=D,c=3,graph_density=3*int(np.log(n_user)*n_user))

# %% [markdown]
# On représente tous les n_users :

# %%
plt.figure(figsize=(10,10))
nx.draw(Online.V)
plt.show()
#plt.savefig('graphe_initial.png')

# %%
#paramètrage des algorithmes
sigma=0.3
alpha=5
alpha2=1
z=0
method = "fixed design"

# %% [markdown]
# #### Algorithme CLUB

# %%
list_m, list_CB, list_omega, list_payoff, list_random_payoff, regret_cum, regret_cum_random, V = Online.CLUB(sigma=sigma,alpha=alpha,alpha2=alpha2,z=z,method=method)

# %% [markdown]
# #### Algorithme LINUCB_IND

# %%
list_payoff_Lin,regret_cum_Lin,regret_cum_random_Lin = Online.LinUCB_IND(sigma=sigma,alpha=alpha,method=method)

# %% [markdown]
# Regardons l'évolution du nombre de Cluster au fur et à mesure des ittérations :

# %%
fig = plt.figure()
plt.plot(list_m)
plt.title("Evolution du nombre de cluster")
plt.show()
#plt.savefig('nombre_clusters_evol.png')

# %% [markdown]
# Observons l'évolution des Confidence Bound :

# %%
plt.figure()
plt.plot(list_CB)
plt.title("Evolution des Confidence Bound sur les 10k premières itérations")
plt.xlim(0,10000)
plt.show()
#plt.savefig('CB_evol.png')

# %% [markdown]
# Observons l'évolution de la payoff cumulée en fonction des ittérations :

# %%
plt.figure()
plt.plot(Online.payoff_cum(list_payoff)[1000:Online.T])
plt.plot(Online.payoff_cum(list_payoff_Lin)[1000:Online.T])
plt.title("Evolution de la payoff cumulée")
plt.legend(["CLUB","LinUCB_IND"])
plt.show()
#plt.savefig('payoff_cumul.png')

# %% [markdown]
# Observons enfin le regret cumulé associé :

# %%
#plt.plot(-regret_cum_random)
plt.figure()
plt.plot(regret_cum/regret_cum_random)
plt.plot(regret_cum_Lin/regret_cum_random_Lin)
plt.legend(["CLUB","LinUCB_IND"])
plt.xlim(1000,)
plt.ylim(0,1)
plt.xlabel("itérations")
plt.ylabel("regret cumulé relatif")
plt.title("Evolution du regret cumulé relatif au cas aléatoire")
plt.show()
plt.savefig('regret_cumul.png')

# %% [markdown]
# Les nouveux clusters sont :

# %%
plt.figure(figsize=(10,10))
nx.draw(V)
plt.show()

# %%
Online.U
# Out:
# array([[ 1.        ,  1.        , -1.        ,  1.        ,  1.        ],
#        [ 0.70014974, -0.60295059,  0.06889754, -0.58198488, -0.46333779],
#        [-0.10331506, -0.42922906,  0.24948071, -0.49129641,  0.27248283],
#        [ 0.11398497,  0.26882232, -0.68191843,  0.1958343 ,  0.5728273 ],
#        [ 0.62337793, -0.51055138,  0.05555515, -0.48930022, -0.38090565],
#        [-0.09210051, -0.37571817,  0.2052624 , -0.43096077,  0.22807741],
#        [ 0.10115556,  0.23758922, -0.60850984,  0.17286601,  0.50786925],
#        [ 0.57792915, -0.46458083,  0.04979808, -0.44465157, -0.34101996],
#        [-0.08318033, -0.34415895,  0.18315397, -0.3975556 ,  0.20707802],
#        [ 0.09330817,  0.21873287, -0.56448979,  0.15929242,  0.46863592],
#        [ 0.54639981, -0.43432622,  0.04652962, -0.41474323, -0.31749868],
#        [-0.07860197, -0.32341505,  0.16809464, -0.3732082 ,  0.19189005],
#        [ 0.08666145,  0.20568866, -0.53346574,  0.14861961,  0.44212362],
#        [ 0.5211679 , -0.41167622,  0.04298325, -0.39387646, -0.29846978],
#        [-0.07497764, -0.30651705,  0.15713843, -0.35555565,  0.18118021],
#        [ 0.08355871,  0.19623   , -0.51013355,  0.14176684,  0.42181262],
#        [ 0.50140189, -0.39365369,  0.04104274, -0.37732512, -0.2857917 ],
#        [-0.07108272, -0.29331723,  0.15000934, -0.3411345 ,  0.17255082],
#        [ 0.0798393 ,  0.18732145, -0.49029683,  0.13582241,  0.40526576],
#        [ 0.4849818 , -0.38018369,  0.0388317 , -0.36355156, -0.27446647],
#        [-0.06844603, -0.28352002,  0.14292782, -0.32949066,  0.16698827],
#        [ 0.07671296,  0.18053574, -0.47458845,  0.13089687,  0.39240992],
#        [ 0.47089766, -0.36844671,  0.03810549, -0.35180773, -0.26422781],
#        [-0.06625121, -0.27565078,  0.13830544, -0.31936511,  0.16081067],
#        [ 0.07465583,  0.17461719, -0.46148874,  0.12695478,  0.38031725],
#        [ 0.45964507, -0.35812442,  0.03676373, -0.34250869, -0.2574679 ],
#        [-0.06470519, -0.26746896,  0.13304456, -0.31079901,  0.15652297],
#        [ 0.07311103,  0.16981003, -0.44947719,  0.12405078,  0.37135088],
#        [ 0.44852557, -0.34893589,  0.03547118, -0.33383045, -0.25023084],
#        [-0.06356624, -0.2614144 ,  0.13023758, -0.30281677,  0.15198733],
#        [ 0.07083013,  0.16589505, -0.43846116,  0.12126872,  0.36242274],
#        [ 0.43941473, -0.34117071,  0.03401777, -0.32524392, -0.24373356],
#        [-0.06028797, -0.25550498,  0.12715533, -0.29578676,  0.14784172],
#        [ 0.06770638,  0.16148808, -0.42987145,  0.11751603,  0.35458778],
#        [ 0.43043824, -0.3341295 ,  0.03333758, -0.31849423, -0.23811128],
#        [-0.06025053, -0.2495423 ,  0.12434797, -0.29014804,  0.14527545],
#        [ 0.06724726,  0.15853765, -0.42121929,  0.11464843,  0.34668221],
#        [ 0.42308545, -0.32825204,  0.03272515, -0.31243013, -0.2347767 ],
#        [-0.05830075, -0.2449189 ,  0.12071483, -0.28468028,  0.1417448 ],
#        [ 0.06546315,  0.15537115, -0.41337243,  0.11272504,  0.3408684 ],
#        [ 0.41569687, -0.3224567 ,  0.03227387, -0.30646319, -0.22948841],
#        [-0.05718248, -0.24063582,  0.11877388, -0.27890887,  0.13956248],
#        [ 0.06572074,  0.15297855, -0.40658245,  0.11142518,  0.33587666],
#        [ 0.40904236, -0.31705099,  0.03191859, -0.30196566, -0.22568151],
#        [-0.05623084, -0.23691847,  0.11705726, -0.27565672,  0.1371233 ],
#        [ 0.06359518,  0.14973519, -0.40020355,  0.10923277,  0.33018829],
#        [ 0.40311094, -0.31159817,  0.03075524, -0.29763381, -0.22259357],
#        [-0.05529745, -0.23311718,  0.11455992, -0.27146463,  0.13447029],
#        [ 0.06221488,  0.14757363, -0.39465546,  0.10674388,  0.32508938],
#        [ 0.39664806, -0.30747201,  0.03079961, -0.29308202, -0.21798476],
#        [-0.05511109, -0.22930068,  0.11347593, -0.2671385 ,  0.13254367],
#        [ 0.06182641,  0.14563557, -0.38941274,  0.10500928,  0.3202864 ],
#        [ 0.39170786, -0.30343447,  0.02926011, -0.28848458, -0.21546912],
#        [-0.05431168, -0.2264519 ,  0.11153148, -0.26397523,  0.1298318 ],
#        [ 0.0610755 ,  0.14351827, -0.38350801,  0.10433453,  0.31610517],
#        [ 0.38738477, -0.29954176,  0.02918786, -0.28455427, -0.21251338],
#        [-0.05305342, -0.22261478,  0.10900012, -0.25966055,  0.12879133],
#        [ 0.06034848,  0.14158815, -0.37932854,  0.10253278,  0.31203543],
#        [ 0.3822159 , -0.29590713,  0.02943826, -0.28119209, -0.20927662],
#        [-0.05232838, -0.22039543,  0.10778865, -0.25706467,  0.12657757]])

# %%
Online.center
# Out:
# array([[ 0.1511389 ,  0.95711184,  0.41013893, -0.5461939 , -0.94443888],
#        [-0.95183284, -0.25424143,  0.23871892,  0.14631997,  0.12320143],
#        [-0.26677945, -0.13891803,  0.88022687,  0.82478039, -0.30472382]])
